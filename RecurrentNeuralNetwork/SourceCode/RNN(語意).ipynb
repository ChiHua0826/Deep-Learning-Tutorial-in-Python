# %%
#引用tensorflow函式庫
import tensorflow
#引用keras函式庫
import keras
#引用csv函式庫
import csv
#引用numpy函式庫
import numpy
#引用pyplot函式庫
import matplotlib.pyplot as plot

#讀取訓練資料
X = numpy.loadtxt("../資料集/X(語意).csv", delimiter=",")
Y = numpy.loadtxt("../資料集/Y(語意).csv", delimiter=",")
#轉換為3x2矩陣大小
X = X.reshape(X.shape[0], 3, 2).astype('float32')
# Out:
# Using TensorFlow backend.

# %%
#設定亂數種子
numpy.random.seed(1)

#設定神經網路結構
model = keras.models.Sequential()
model.add(keras.layers.SimpleRNN(1, activation = "linear", use_bias = True, input_shape =(3, 2)))
model.add(keras.layers.Dense(2, activation = 'softmax')) #輸入參數: 1個, 輸出參數: 1個, 線性函式

#設定神經網路學習目標
model.compile(loss='categorical_crossentropy', optimizer = 'sgd', metrics = ['acc']) #損失函式: 交叉熵, 最佳化方法: 梯度下降

# %%
def show_train_history(train_history, x1, x2):
    plot.plot(train_history.history[x1])
    plot.plot(train_history.history[x2])
    plot.title('Train History')
    plot.ylabel('train')
    plot.xlabel('Epoch')
    plot.legend([x1, x2], loc = 'upper right')
    plot.show()

# %%
#訓練神經網路
train_history = model.fit(X, Y, epochs = 500, batch_size = 1) #訓練回合數: 500, #逐筆修正權重
#顯示訓練過程
show_train_history(train_history, 'loss', 'acc')

#顯示訓練錯誤率
scores = model.evaluate(X, Y)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))

#顯示神經網路權重值
print(model.get_weights())
# Out:
# Epoch 1/500
# 4/4 [==============================] - 0s 43ms/step - loss: 1.0085 - acc: 0.2500
# Epoch 2/500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.9224 - acc: 0.2500
# Epoch 3/500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8588 - acc: 0.2500
# Epoch 4/500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.8090 - acc: 0.5000
# Epoch 5/500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7701 - acc: 0.5000
# Epoch 6/500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7380 - acc: 0.5000
# Epoch 7/500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.7117 - acc: 0.5000
# Epoch 8/500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6893 - acc: 0.5000
# Epoch 9/500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6705 - acc: 0.5000
# Epoch 10/500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6542 - acc: 0.5000
# Epoch 11/500
# ...

# %%
#將測試資料代入模型進行預測,並取得預測結果
predictions = model.predict(X)
print(predictions)
# Out:
# [[0.9968581  0.00314192]
#  [0.9946978  0.0053022 ]
#  [0.9670164  0.03298365]
#  [0.02939807 0.970602  ]]
