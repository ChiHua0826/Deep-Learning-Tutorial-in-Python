# %%
#引用tensorflow函式庫
import tensorflow
#引用keras函式庫
import keras
#引用csv函式庫
import csv
#引用numpy函式庫
import numpy
#引用pyplot函式庫
import matplotlib.pyplot as plot

#讀取訓練資料
X = numpy.loadtxt("../資料集/X_斜線案例.csv", delimiter=",")
Y = numpy.loadtxt("../資料集/Y_斜線案例.csv", delimiter=",")
#轉換為2x2矩陣大小
X = X.reshape(X.shape[0], 2, 2, 1).astype('float32')
# Out:
# Using TensorFlow backend.

# %%
#設定亂數種子
numpy.random.seed(1)

#設定神經網路結構
model = keras.models.Sequential()
model.add(keras.layers.Conv2D(filters = 1, kernel_size = (2, 2), activation = 'linear', input_shape = (2, 2, 1)))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(1, activation = 'linear')) #輸入參數: 1個, 輸出參數: 1個, 線性函式

#設定神經網路學習目標
model.compile(loss='mean_squared_error', optimizer = keras.optimizers.SGD(lr = 0.01, momentum = 0.5), metrics = ['mae']) #損失函式: 最小平方誤差, 最佳化方法: 梯度下降

# %%
def show_train_history(train_history, x1, x2):
    plot.plot(train_history.history[x1])
    plot.plot(train_history.history[x2])
    plot.title('Train History')
    plot.ylabel('train')
    plot.xlabel('Epoch')
    plot.legend([x1, x2], loc = 'upper right')
    plot.show()

# %%
#訓練神經網路
train_history = model.fit(X, Y, epochs = 1000, batch_size = 1) #訓練回合數: 1000, #逐筆修正權重
#顯示訓練過程
show_train_history(train_history, 'loss', 'mean_absolute_error')

#顯示訓練錯誤率
scores = model.evaluate(X, Y)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))

#顯示神經網路權重值
print(model.get_weights())
# Out:
# Epoch 1/1000
# 3/3 [==============================] - 0s 31ms/step - loss: 0.4622 - mean_absolute_error: 0.4441
# Epoch 2/1000
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3900 - mean_absolute_error: 0.3633
# Epoch 3/1000
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3344 - mean_absolute_error: 0.3782
# Epoch 4/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2922 - mean_absolute_error: 0.3662
# Epoch 5/1000
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2856 - mean_absolute_error: 0.4082
# Epoch 6/1000
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2522 - mean_absolute_error: 0.4020
# Epoch 7/1000
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2423 - mean_absolute_error: 0.4101
# Epoch 8/1000
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2400 - mean_absolute_error: 0.4297
# Epoch 9/1000
# ...

# %%
#將測試資料代入模型進行預測,並取得預測結果
predictions = model.predict(X)
print(predictions)
# Out:
# [[4.6193600e-07]
#  [1.7881393e-07]
#  [9.9999940e-01]]
