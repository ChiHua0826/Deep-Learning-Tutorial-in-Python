# %%
#引用tensorflow函式庫
import tensorflow
#引用keras函式庫
import keras
#引用csv函式庫
import csv
#引用numpy函式庫
import numpy
#引用pyplot函式庫
import matplotlib.pyplot as plot

#類別數量
num_classes = 10
#圖片長寬
img_rows = 28
img_cols = 28

#讀取訓練資料
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()
#正規化
X = X / 255
#轉換為2x2矩陣大小
X = X_train.reshape(X_train.shape[0], img_rows, img_cols, 1) #圖片大小為28x28
Y = keras.utils.to_categorical(y_train, num_classes)
# Out:
# Using TensorFlow backend.

# %%
#設定亂數種子
numpy.random.seed(1)

#設定神經網路結構
model = keras.models.Sequential()
model.add(keras.layers.Conv2D(filters = 1, kernel_size = (3, 3), activation = 'relu', input_shape = (img_rows, img_cols, 1)))
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(num_classes, activation = 'softmax'))

#設定神經網路學習目標
model.compile(loss='categorical_crossentropy', optimizer = 'sgd', metrics = ['acc']) #損失函式: 交叉熵, 最佳化方法: 梯度下降

# %%
def show_train_history(train_history, x1, x2):
    plot.plot(train_history.history[x1])
    plot.plot(train_history.history[x2])
    plot.title('Train History')
    plot.ylabel('train')
    plot.xlabel('Epoch')
    plot.legend([x1, x2], loc = 'upper right')
    plot.show()

# %%
#訓練神經網路
train_history = model.fit(X, Y, epochs = 300, batch_size = 60000) #訓練回合數: 300, 每60000筆修正權重
#顯示訓練過程
show_train_history(train_history, 'loss', 'acc')

#顯示訓練錯誤率
scores = model.evaluate(X, Y)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))

#顯示神經網路權重值
print(model.get_weights())
# Out:
# Epoch 1/300
# 60000/60000 [==============================] - 3s 57us/step - loss: 2.4673 - acc: 0.1181
# Epoch 2/300
# 60000/60000 [==============================] - 3s 53us/step - loss: 2.4468 - acc: 0.1198
# Epoch 3/300
# 60000/60000 [==============================] - 3s 55us/step - loss: 2.4282 - acc: 0.1214
# Epoch 4/300
# 60000/60000 [==============================] - 3s 56us/step - loss: 2.4110 - acc: 0.1230
# Epoch 5/300
# 60000/60000 [==============================] - 3s 57us/step - loss: 2.3951 - acc: 0.1251
# Epoch 6/300
# 60000/60000 [==============================] - 3s 54us/step - loss: 2.3802 - acc: 0.1268
# Epoch 7/300
# 60000/60000 [==============================] - 3s 53us/step - loss: 2.3663 - acc: 0.1288
# Epoch 8/300
# 60000/60000 [==============================] - 3s 55us/step - loss: 2.3533 - acc: 0.1313
# Epoch 9/300
# 60000/60000 [==============================] - 3s 54us/step - loss: 2.3409 - acc: 0.1337
# Epoch 10/300
# ...

# %%
#將測試資料代入模型進行預測,並取得預測結果
predictions = model.predict(X)
print(predictions)
# Out:
# [[4.2391801e-03 1.5227361e-04 4.5561003e-03 ... 3.7462416e-03
#   2.6903818e-03 9.0145261e-04]
#  [9.9834311e-01 2.2059540e-07 1.2527861e-05 ... 9.5644109e-06
#   9.6555035e-05 1.6456384e-05]
#  [2.7024290e-03 1.6343025e-04 8.8466499e-03 ... 5.3502717e-03
#   3.4289945e-02 1.8967728e-01]
#  ...
#  [5.9974391e-04 1.5144881e-04 3.6482666e-05 ... 1.4806493e-03
#   1.3704997e-02 4.6561761e-03]
#  [5.9526008e-02 1.3780118e-04 1.2423550e-02 ... 3.6662740e-03
#   1.0914478e-03 9.8099522e-03]
#  [5.9255864e-02 1.9421137e-03 1.1975645e-02 ... 6.7455866e-03
#   6.7338985e-01 2.0780878e-01]]
